# %%
import numpy as np

# %%
N_samples = 500

sample_size = 200

# %%
die_throw_samples = np.random.randint(1,7,size=(N_samples,sample_size))

# %%
die_throw_samples
# Out:
# array([[2, 1, 1, ..., 6, 4, 2],
#        [2, 1, 2, ..., 1, 3, 2],
#        [1, 5, 6, ..., 1, 1, 5],
#        ...,
#        [4, 2, 4, ..., 1, 3, 3],
#        [3, 4, 5, ..., 2, 6, 5],
#        [4, 4, 6, ..., 5, 3, 2]])

# %%
sample_means = np.mean(die_throw_samples,axis=1)

# %%
mean_of_sample_means = np.mean(sample_means)

print(mean_of_sample_means)
# Out:
# 3.48915

# %%
import seaborn as sns

# %%
import scipy.stats as s

# %%
sns.distplot(sample_means,bins=10,kde=False,fit=s.norm)

plt.xlabel("Sample Mean of Size sample_size")

plt.ylabel("Relative Frequency(Sample Mean = k)")
# Out:
# Text(0, 0.5, 'Relative Frequency(Sample Mean = k)')
